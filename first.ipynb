# %% [markdown]
# ## Задача 1

# %%
km = int(input('Care este viteza in km/h?:'))
print(f'Viteza exprimata in km/h este egala cu {km} KM/H')
print(f'Viteza exprimata in mph este egala cu? {0.6214 * km} MPH')
# Out:
# Care este viteza in km/h?: 30
# Viteza exprimata in km/h este egala cu 30 KM/H
# Viteza exprimata in mph este egala cu? 18.642 MPH

# %% [markdown]
# ## Задача 2

# %%
a = int(input('Care este valoarea pentru nr. a? a ='))
b = int(input('Care este valoarea pentru nr. b? b ='))
print(f'a + b ={a+b} ; a - b = {a-b}')
print(f'a * b = {a*b} ; a : b = {a/b}')
# Out:
# Care este valoarea pentru nr. a? a = 4
# Care este valoarea pentru nr. b? b = 6
# a + b =10 ; a - b = -2
# a * b = 24 ; a : b = 0.6666666666666666

# %% [markdown]
# ## Задача 3

# %%
a = int(input('Care este valoarea pentru nr. a? a ='))
print(f'{a} , {a * a}, {(a * a) * a}')
# Out:
# Care este valoarea pentru nr. a? a = 4
# 4 , 16, 64

# %% [markdown]
# ## Задача 4

# %%
a = int(input('Care este temperatura in grade Celsius?:'))
print(f'Temperatura in grade Celsius este {a} grade C')
print(f'Temperatura in grade Fahrenheit este {9/5*a+32} grade F')
# Out:
# Care este temperatura in grade Celsius?: 27
# Temperatura in grade Celsius este 27 grade C
# Temperatura in grade Fahrenheit este 80.6 grade F

# %% [markdown]
# ## Задача 5

# %%
a = int(input('Care este lungimea dreptungului?:'))
b = int(input('Care este latimea dreptungului?:'))
print(f'ARIA = {a * b} PERIMETRUL = {(a + b) * 2}')
# Out:
# Care este lungimea dreptungului?: 4
# Care este latimea dreptungului?: 6
# ARIA = 24 PERIMETRUL = 20

# %% [markdown]
# ## Задача 6

# %%
import math
from math import pi
a = int(input('Care este raza cercului?:'))
print(f'Diametrul cercului este: {2*a}')
print(f'Lungimea cercului este: {2*pi*a}')
print(f'Aria cercului este: {pi*a**2}')
# Out:
# Care este raza cercului?: 5
# Diametrul cercului este: 10
# Lungimea cercului este: 31.41592653589793
# Aria cercului este: 78.53981633974483

# %% [markdown]
# ## Задача 7

# %%
nume = "Andrei"
varsta = 37
angajat = True
print(nume, varsta, angajat)
# Out:
# Andrei 37 True

# %% [markdown]
# ## Задача 8

# %%
x = 20
y = 4
print (x - y)
# Out:
# 16

# %% [markdown]
# ## Задача 9

# %%
prenume = input('Introducu prenumele:')
nume = input('Introducu numele:')
varsta = input('Introducu varsta:')
print(f'Salut {prenume} {nume} ai implinit {varsta} ani!')
# Out:
# Introducu prenumele: Cocostirco
# Introducu numele: Daniil
# Introducu varsta: 19
# Salut Cocostirco Daniil ai implinit 19 ani!
